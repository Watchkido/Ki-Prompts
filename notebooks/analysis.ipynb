# %% [markdown]
# # Datenanalyse

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../data/processed/output.csv')
display(df.head())
df.describe()
df.hist(figsize=(10,6))
plt.show()

# %%
print(f"platzhalter  wie 019_KI_Prompts oder watchkido verwenden")

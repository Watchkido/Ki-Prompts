# %% [markdown]
# # Nächste Schritte
#
# Ziel des Kurs:
# - Verständnis Data Cleansing
# - Verständnis Data Transformation
# - Verständnis Feature Engineering
#
# Nicht-Ziel:
# - Data Integration
# - Data Reduction
#
# Fokus:
# - Strukturierte Daten
#
# Nächste Schritte:
# - unstrukturierte Daten

# %% [markdown]
# # Literatur
#
# - Foster Provost and Tom Fawcett. Data Science für Unternehmen: Data Mining und datenanalytisches Denken praktisch anwenden. MITP-Verlag, 2017.
#
# - Peter Bruce, Andrew Bruce, and Peter Gedeck. Praktische Statistik für Data Scientists: 50+ essentielle Konzepte mit R und Python. O'Reilly, 2020.
#
# - Wes McKinney. Datenanalyse mit Python. O'Reilly, 2015.
#
# - Alice Zheng and Amanda Casari. Feature Engineering for Machine Learning. O'Reilly, 2018.
#
# Sehr empfehlenswert:
#
# - https://medium.com/
#
# - https://towardsdatascience.com/

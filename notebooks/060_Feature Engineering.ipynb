# %% [markdown]
# # Feature Engineering
# Feature Engineering ist der Prozess der Erstellung neuer Merkmale.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Quelle Originaldatenset: https://www.kaggle.com/datasets/flashgordon/usa-airport-dataset

# %%
airports = pd.read_csv (r'short_airports.csv')
airports
# Out:
#     Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0           41    396       22       103  1990-11-01             284093
# 1           88    342       19       103  1990-12-01             284093
# 2           11     72        4       103  1990-10-01             284093
# 3            0     18        1       156  1990-02-01             147300
# 4           11     18        1       156  1990-03-01             147300
# 5            2     72        4       156  1990-01-01             147300
# 6            7     18        1       156  1990-09-01             147300
# 7            7     36        2       156  1990-11-01             147300
# 8           41    396       22       103  1990-11-01             284093
# 9           88    342       19       103  1990-12-01             284093
# 10          11     72        4       103  1990-10-01             284093
# 11           0     18        1       156  1990-02-01             147300
# ...

# %%
airports['empty_seats'] = airports['Seats'] - airports['Passengers']
airports
# Out:
#     Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0           41    396       22       103  1990-11-01             284093
# 1           88    342       19       103  1990-12-01             284093
# 2           11     72        4       103  1990-10-01             284093
# 3            0     18        1       156  1990-02-01             147300
# 4           11     18        1       156  1990-03-01             147300
# 5            2     72        4       156  1990-01-01             147300
# 6            7     18        1       156  1990-09-01             147300
# 7            7     36        2       156  1990-11-01             147300
# 8           41    396       22       103  1990-11-01             284093
# 9           88    342       19       103  1990-12-01             284093
# 10          11     72        4       103  1990-10-01             284093
# 11           0     18        1       156  1990-02-01             147300
# ...

# %%
airports['Fly_date'] = pd.to_datetime(airports['Fly_date'])
airports.dtypes
# Out:
# Passengers                         int64
# Seats                              int64
# Flights                            int64
# Distance                           int64
# Fly_date                  datetime64[ns]
# Origin_population                  int64
# Destination_population             int64
# Org_airport_lat                  float64
# Org_airport_long                 float64
# Dest_airport_lat                 float64
# Dest_airport_long                float64
# empty_seats                        int64
# dtype: object

# %%
airports['Fly_day'] = airports['Fly_date'].dt.day_name()
airports
# Out:
#     Passengers  Seats  Flights  Distance   Fly_date  Origin_population  \
# 0           41    396       22       103 1990-11-01             284093
# 1           88    342       19       103 1990-12-01             284093
# 2           11     72        4       103 1990-10-01             284093
# 3            0     18        1       156 1990-02-01             147300
# 4           11     18        1       156 1990-03-01             147300
# 5            2     72        4       156 1990-01-01             147300
# 6            7     18        1       156 1990-09-01             147300
# 7            7     36        2       156 1990-11-01             147300
# 8           41    396       22       103 1990-11-01             284093
# 9           88    342       19       103 1990-12-01             284093
# 10          11     72        4       103 1990-10-01             284093
# 11           0     18        1       156 1990-02-01             147300
# ...

# %%
airports['Fly_month'] = airports['Fly_date'].dt.month_name()
airports
# Out:
#     Passengers  Seats  Flights  Distance   Fly_date  Origin_population  \
# 0           41    396       22       103 1990-11-01             284093
# 1           88    342       19       103 1990-12-01             284093
# 2           11     72        4       103 1990-10-01             284093
# 3            0     18        1       156 1990-02-01             147300
# 4           11     18        1       156 1990-03-01             147300
# 5            2     72        4       156 1990-01-01             147300
# 6            7     18        1       156 1990-09-01             147300
# 7            7     36        2       156 1990-11-01             147300
# 8           41    396       22       103 1990-11-01             284093
# 9           88    342       19       103 1990-12-01             284093
# 10          11     72        4       103 1990-10-01             284093
# 11           0     18        1       156 1990-02-01             147300
# ...

# %% [markdown]
# Quelle zur Distanzberechnung: https://towardsdatascience.com/heres-how-to-calculate-distance-between-2-geolocations-in-python-93ecab5bbba4

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
   r = 6371
   phi1 = np.radians(lat1)
   phi2 = np.radians(lat2)
   delta_phi = np.radians(lat2 - lat1)
   delta_lambda = np.radians(lon2 - lon1)
   a = np.sin(delta_phi / 2)**2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2)**2
   res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a)))
   return np.round(res, 2)

# %%
direct_distance = haversine_distance(airports.Org_airport_lat, airports.Org_airport_long, airports.Dest_airport_lat, airports.Dest_airport_long)

airports['haversine_distance'] = direct_distance
airports
# Out:
#     Passengers  Seats  Flights  Distance   Fly_date  Origin_population  \
# 0           41    396       22       103 1990-11-01             284093
# 1           88    342       19       103 1990-12-01             284093
# 2           11     72        4       103 1990-10-01             284093
# 3            0     18        1       156 1990-02-01             147300
# 4           11     18        1       156 1990-03-01             147300
# 5            2     72        4       156 1990-01-01             147300
# 6            7     18        1       156 1990-09-01             147300
# 7            7     36        2       156 1990-11-01             147300
# 8           41    396       22       103 1990-11-01             284093
# 9           88    342       19       103 1990-12-01             284093
# 10          11     72        4       103 1990-10-01             284093
# 11           0     18        1       156 1990-02-01             147300
# ...
